# %%
import glob

# %%
from PIL import Image
from numpy import asarray

# %%
import numpy as np

# %%
images = []
for f in glob.iglob(r"C:\Users\kwnst\OneDrive\Υπολογιστής\DL_datasets\Bike Helmet Detection.v1-bboxblur-resized.retinanet\train\*"):
    images.append(np.asarray(Image.open(f)))

images = np.array(images)

# %%
images.shape
# Out:
# (1182, 416, 416, 3)

# %%
import matplotlib as plt
from ipywidgets import interact

# %%
digit = images[1]
plt.pyplot.imshow(digit)

# %%
@interact
def show_image(index=100):
    digit = images[index]
    plt.pyplot.imshow(digit, cmap=plt.cm.binary)
# Out:
# interactive(children=(IntSlider(value=100, description='index', max=300, min=-100), Output()), _dom_classes=('…

# %%
# load the image
image = Image.open(r"C:\Users\kwnst\OneDrive\Υπολογιστής\DL_datasets\Bike Helmet Detection.v1-bboxblur-resized.retinanet\train\BikesHelmets714_png_jpg.rf.62e2c95875f82a6677e72abbec1c0e51.jpg")
# convert image to numpy array
data = asarray(image)
print(type(data))
# summarize shape
print(data.shape)

# create Pillow image
image2 = Image.fromarray(data)
print(type(image2))

# summarize image details
print(image2.mode)
print(image2.size)
# Out:
# <class 'numpy.ndarray'>
# (416, 416, 3)
# <class 'PIL.Image.Image'>
# RGB
# (416, 416)

# %%
data
# Out:
# array([[[ 50,  80,  44],
#         [ 58,  88,  52],
#         [ 56,  83,  50],
#         ...,
#         [ 35,  71,  10],
#         [ 27,  65,   4],
#         [ 27,  66,   3]],
#
#        [[ 31,  61,  27],
#         [ 33,  63,  29],
#         [ 32,  59,  26],
#         ...,
#         [ 34,  69,  11],
#         [ 26,  64,   3],
#         [ 25,  64,   1]],
#
#        [[ 25,  54,  23],
#         [ 31,  60,  29],
#         [ 40,  67,  36],
#         ...,
#         [ 29,  64,   6],
#         [ 21,  59,   0],
#         [ 19,  57,   0]],
#
#        ...,
#
#        [[153, 151, 154],
#         [148, 146, 149],
#         [150, 148, 151],
#         ...,
#         [125, 123, 126],
#         [135, 133, 136],
#         [139, 137, 140]],
#
#        [[138, 133, 137],
#         [141, 136, 140],
#         [154, 149, 153],
#         ...,
#         [128, 126, 129],
#         [141, 139, 142],
#         [148, 146, 149]],
#
#        [[143, 138, 142],
#         [141, 136, 140],
#         [151, 146, 150],
# ...
